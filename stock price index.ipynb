# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500= sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
# 2024-02-22 00:00:00-05:00  5038.830078  5094.390137  5038.830078  5087.029785
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-02-08 00:00:00-05:00', '2024-02-09 00:00:00-05:00',
#                '2024-02-12 00:00:00-05:00', '2024-02-13 00:00:00-05:00',
#                '2024-02-14 00:00:00-05:00', '2024-02-15 00:00:00-05:00',
#                '2024-02-16 00:00:00-05:00', '2024-02-20 00:00:00-05:00',
#                '2024-02-21 00:00:00-05:00', '2024-02-22 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24151, freq=None)

# %%
import matplotlib.pyplot as plt

# %%
def plot_closing_price(df):
    """
    Plot the closing price of a DataFrame across the index.

    Parameters:
    - df: DataFrame with a DatetimeIndex and a 'Close' column.
    """
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Closing Price', color='blue')
    plt.title('Closing Price Over Time')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_closing_price(sp500)

# %%
sp500['tomorrow'] = sp500['Close'].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
# 2024-02-22 00:00:00-05:00  5038.830078  5094.390137  5038.830078  5087.029785
#
# ...

# %%
print(sp500.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'tomorrow'], dtype='object')

# %%
sp500['Target'] = (sp500['tomorrow'] > sp500['Close']).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
# 2024-02-22 00:00:00-05:00  5038.830078  5094.390137  5038.830078  5087.029785
#
# ...

# %%
sp500 =sp500.loc["1999-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1999-01-04 00:00:00-05:00  1229.229980  1248.810059  1219.099976  1228.099976
# 1999-01-05 00:00:00-05:00  1228.099976  1246.109985  1228.099976  1244.780029
# 1999-01-06 00:00:00-05:00  1244.780029  1272.500000  1244.780029  1272.339966
# 1999-01-07 00:00:00-05:00  1272.339966  1272.339966  1257.680054  1269.729980
# 1999-01-08 00:00:00-05:00  1269.729980  1278.239990  1261.819946  1275.089966
# ...                                ...          ...          ...          ...
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
# 2024-02-22 00:00:00-05:00  5038.830078  5094.390137  5038.830078  5087.029785
#
# ...

# %%
#TRAINING THE MODEL

# %%
print(sp500.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'tomorrow', 'Target'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train =sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.metrics import precision_score

preds= model.predict(test[predictors])
# Out:
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
preds
# Out:
# Date
# 2023-09-29 00:00:00-04:00    1
# 2023-10-02 00:00:00-04:00    1
# 2023-10-03 00:00:00-04:00    0
# 2023-10-04 00:00:00-04:00    1
# 2023-10-05 00:00:00-04:00    1
#                             ..
# 2024-02-15 00:00:00-05:00    0
# 2024-02-16 00:00:00-05:00    0
# 2024-02-20 00:00:00-05:00    0
# 2024-02-21 00:00:00-05:00    0
# 2024-02-22 00:00:00-05:00    0
# Length: 100, dtype: int32

# %%
import pandas as pd
preds = pd.Series(preds, index= test.index)

# %%
combined = pd. concat([test["Target"], preds], axis=1)

# %%
preds
# Out:
# Date
# 2023-09-29 00:00:00-04:00    1
# 2023-10-02 00:00:00-04:00    1
# 2023-10-03 00:00:00-04:00    0
# 2023-10-04 00:00:00-04:00    1
# 2023-10-05 00:00:00-04:00    1
#                             ..
# 2024-02-15 00:00:00-05:00    0
# 2024-02-16 00:00:00-05:00    0
# 2024-02-20 00:00:00-05:00    0
# 2024-02-21 00:00:00-05:00    0
# 2024-02-22 00:00:00-05:00    0
# Length: 100, dtype: int32

# %%
precision_score(test["Target"], preds)
# Out:
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
combined=pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
     model.fit(train[predictors], train["Target"])
     preds= model. predict(test[predictors])
     preds=pd.Series(preds, index= test.index, name="predictions")
     combined = pd.concat([test["Target"], preds], axis=1)
     return combined

# %%
def backtest(data, model, predictors, start=0, step=100):
    all_predictions = []  # Initialize an empty list to store predictions
    for i in range(start, len(data)-step, step):
        train = data.iloc[i:i+1].copy()
        test = data.iloc[i:i+step].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions=backtest(sp500, model, predictors)
# Out:
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
predictions["predictions"]. value_counts()
# Out:
# predictions
# 1    3400
# 0    2900
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["predictions"])
# Out:
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\BRIAN GILLO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
predictions["Target"].value_counts() /predictions.shape[0]
# Out:
# Target
# 1    0.533333
# 0    0.466667
# Name: count, dtype: float64

# %%
horizons = [2, 5, 60, 100, 250, 1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500['Close'].rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500["Close"].shift(1).rolling(horizon).sum()
    
    new_predictors += [ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1999-01-04 00:00:00-05:00  1229.229980  1248.810059  1219.099976  1228.099976
# 1999-01-05 00:00:00-05:00  1228.099976  1246.109985  1228.099976  1244.780029
# 1999-01-06 00:00:00-05:00  1244.780029  1272.500000  1244.780029  1272.339966
# 1999-01-07 00:00:00-05:00  1272.339966  1272.339966  1257.680054  1269.729980
# 1999-01-08 00:00:00-05:00  1269.729980  1278.239990  1261.819946  1275.089966
# ...                                ...          ...          ...          ...
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
# 2024-02-22 00:00:00-05:00  5038.830078  5094.390137  5038.830078  5087.029785
#
# ...

# %%
sp500 =sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2002-12-26 00:00:00-05:00   892.469971   903.890015   887.479980   889.659973
# 2002-12-27 00:00:00-05:00   889.659973   890.460022   873.619995   875.400024
# 2002-12-30 00:00:00-05:00   875.400024   882.099976   870.229980   879.390015
# 2002-12-31 00:00:00-05:00   879.390015   881.929993   869.450012   879.820007
# 2003-01-02 00:00:00-05:00   879.820007   909.030029   879.820007   909.030029
# ...                                ...          ...          ...          ...
# 2024-02-14 00:00:00-05:00  4976.439941  5002.520020  4956.450195  5000.620117
# 2024-02-15 00:00:00-05:00  5003.140137  5032.720215  4999.439941  5029.729980
# 2024-02-16 00:00:00-05:00  5031.129883  5038.700195  4999.520020  5005.569824
# 2024-02-20 00:00:00-05:00  4989.319824  4993.709961  4955.020020  4975.509766
# 2024-02-21 00:00:00-05:00  4963.029785  4983.209961  4946.000000  4981.799805
#
# ...

# %%
model= RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)
